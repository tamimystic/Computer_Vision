# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In convultion operation,<br>
#         1. filters<br>
#         2. kernel<br>
#         3. feature extractor<br>
#
#         are same, that means it is this matrix that we use in our convolution operation

# %% [markdown]
# - filter move 1 by 1, its called stride    -> it can be change <br>
#         - 1 means shift filter 1 by 1<br>
#         - 2 means skip 1 column and move<br>
#         - 3 means skip 2 column and move

# %% [markdown]
# multiply filter in images and reduce dimension value <br>
# in row first 3 grid and and all columns
#
# ![image.png](attachment:image.png)

# %% [markdown]
# shift 1 row down and <br>
# multiply filter in images and reduce dimension value <br>
# in row 3 grid and and all columns
#
# ![image.png](attachment:image.png)

# %% [markdown]
# again shift 1 row down and <br>
# multiply filter in images and reduce dimension value <br>
# in row 3 grid and and all columns
#
# ![image.png](attachment:image.png)

# %% [markdown]
# again shift 1 row down and <br>
# multiply filter in images and reduce dimension value <br>
# in row 3 grid and and all columns
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Here we do not use this type of hard coded filter
# ## Here we actually use Backpropagation
# - that means matrix value will be updated randomly based on the loss

# %% [markdown]
# ## CNN Animated/Visualization website
#
# https://deeplizard.com/resource/pavq7noze2
#
# - for black-white images
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - for colorful image
#
# https://medium.com/swlh/convolutional-neural-networks-part-3-convolutions-over-volume-and-the-convnet-layer-91fb7c08e28b
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### if     (28*28) <- (3 * 3) = ? <br>
# here   (m * n) <- (m * n) <br>
# <br>
# formula=(m-n+1) * (m-n+1) <br>
# that means,,, Output_size = (Input_size − Filter_size) + 1

# %% [markdown]
# ## We use multiple filter
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Go ahead we will know
#
# ![image.png](attachment:image.png)
